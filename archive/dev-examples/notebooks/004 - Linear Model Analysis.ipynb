# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm

# %%
np.random.seed(42)
X1 = 2.5 * np.random.randn(100) + 1.5  # First predictor
X2 = 1.5 * np.random.randn(100) + 0.5  # Second predictor
res = 0.5 * np.random.randn(100)  # Generate 100 residual terms
y = 2 + 0.3 * X1 - 0.2 * X2 + res  # Actual values of Y

data = pd.DataFrame({"X1": X1, "X2": X2, "y": y})

# %%
X = sm.add_constant(data[["X1", "X2"]])

# %%
model = sm.OLS(y, X).fit()

# %%
plt.figure()
plt.scatter(model.fittedvalues, model.resid)
plt.axhline(y=0, color="red", linestyle="--")
plt.xlabel("Fitted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.grid(True, ls="--")
plt.show()

# %%
plt.figure(figsize=(12, 6))
sm.qqplot(model.resid, line="45", linestyle="--")
plt.title("Q-Q Plot")
plt.grid(True, ls="--")
plt.show()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.729
# Model:                            OLS   Adj. R-squared:                  0.723
# Method:                 Least Squares   F-statistic:                     130.5
# Date:                Mon, 13 Nov 2023   Prob (F-statistic):           3.12e-28
# Time:                        23:33:57   Log-Likelihood:                -78.308
# No. Observations:                 100   AIC:                             162.6
# Df Residuals:                      97   BIC:                             170.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.9785      0.066     29.974      0.000       1.848       2.110
# X1             0.3452      0.024     14.371      0.000       0.298       0.393
# X2            -0.2041      0.038     -5.353      0.000      -0.280      -0.128
# ==============================================================================
# Omnibus:                        3.125   Durbin-Watson:                   2.220
# Prob(Omnibus):                  0.210   Jarque-Bera (JB):                3.080
# Skew:                           0.108   Prob(JB):                        0.214
# Kurtosis:                       3.832   Cond. No.                         3.38
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
