# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

import h5py

sns.set_theme(style="ticks")

# %%
GTC_DATA_DIR = "/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/data/gtc_quakes_data"
SLOWQUAKES_DATA_DIR = f"{GTC_DATA_DIR}/slowquakes"
MICHEL_DATA_DIR = f"{SLOWQUAKES_DATA_DIR}/Micheletal2019a"

# %%
def mat2val(mat, key):
    return np.array(mat.get(key)).T

mat = h5py.File(f"{MICHEL_DATA_DIR}/dynamical_system_variables_rough.mat", 'r')
mat_keys = sorted([x for x in mat.keys()])
mat_keys
# Out:
# ['#refs#',
#  'Area',
#  'Area_asp',
#  'Area_belt',
#  'Lg_term_slip_Rate',
#  'Nasp',
#  'Npatches',
#  'Npatches_asp',
#  'Npatches_belt',
#  'Nt_u',
#  'Nt_v',
#  'Upotrough_asp',
#  'Upotroughdot_asp',
#  'V0pot_asp',
#  'Vpotrough_asp',
#  'aa',
#  'dirs',
#  'fault_model_IC',
#  'flag_surrogate',
#  'id_IN_AspBorder_SSE',
#  'id_IN_AspBorder_SSE_dilat',
#  'ind_in',
#  'ind_in_belt',
#  'ind_nan',
#  'km2m',
#  'll_geom_center_ll',
#  'mm2m',
#  'shear_modulus',
#  'timeline_u',
#  'timeline_v',
#  'toc_start',
#  'upotrough',
#  'upotrough_asp',
#  'upotrough_belt',
#  'upotroughdot',
#  'upotroughdot_asp',
#  'upotroughdot_belt',
#  'urough',
#  'urough_asp',
#  'urough_belt',
#  'urough_mean',
#  'uroughdot',
#  'uroughdot_asp',
#  'uroughdot_belt',
#  'v0',
#  'v0_asp',
#  'v0_belt',
#  'v0pot',
#  'v0pot_asp',
#  'v0pot_belt',
#  'vpotrough',
#  'vpotrough_asp',
#  'vpotrough_belt',
#  'vrough',
#  'vrough_asp',
#  'vrough_belt']

# %%
plt.plot(mat2val(mat, "v0"));

# %%
plt.plot(mat2val(mat, "v0_belt"));
