# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import xarray as xr

sns.set_theme(style="ticks")

# %%
import matplotlib as mpl

font = {"family": "Arial", "weight": "bold"}
mpl.rc("font", **font)

# %%
GTC_DATA_DIR = "/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/data/gtc_quakes_data"
LABQUAKES_DATA_DIR = f"{GTC_DATA_DIR}/synquakes"
DALZILIO_DATA_DIR = f"{LABQUAKES_DATA_DIR}/DalZilioetal2020"

# %%
dalzilio_FILE_PATH = f"{DALZILIO_DATA_DIR}/DalZilioetal2020sim.nc"

# %%
ds = xr.open_dataset(dalzilio_FILE_PATH)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lon: 128, lat: 20, time: 56826)
# Coordinates:
#   * lon      (lon) float64 1.575e+05 1.55e+05 1.525e+05 ... -1.575e+05 -1.6e+05
#   * lat      (lat) float64 5.75e+04 5.5e+04 5.25e+04 ... 1.5e+04 1.25e+04 1e+04
#   * time     (time) datetime64[ns] 2000-01-01 2000-01-02 ... 2155-08-01
# Data variables:
#     SPR      (time, lat, lon) float32 ...

# %%
plt.figure()
sns.lineplot(data=ds.sel(lon=0, lat=10000), x="time", y="SPR")
plt.xlabel("Year", **font)
plt.ylabel("SPR", **font)
plt.show();
