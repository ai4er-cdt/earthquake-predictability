# %%
import matplotlib.pyplot as plt
import numpy as np

from utils.data_preprocessing import (
    compare_feature_statistics,
    moving_average_causal_filter,
)
from utils.dataset import SlowEarthquakeDataset
from utils.general_functions import set_seed, set_torch_device
from utils.plotting import (
    plot_all_data_results,
    plot_metric_results,
    plot_original_vs_processed_data,
)

# %%
###### Simulated data training #########

# %%
SEED = 42
set_seed(SEED)

device = set_torch_device()
# Out:
# GPU name: NVIDIA A100-SXM4-40GB
# Max GPU memory: 42.297786368 GiB

# %%
EXP = "sim_b698"

dataset = SlowEarthquakeDataset([EXP])
df = SlowEarthquakeDataset.convert_to_df(dataset, EXP)

df.head()
# Out:
#    obs_shear_stress  obs_normal_stress  time
# 0         10.656969          16.801851  0.00
# 1         10.658275          16.802265  0.01
# 2         10.659582          16.802679  0.02
# 3         10.660889          16.803091  0.03
# 4         10.662196          16.803503  0.04

# %%
shear_stress_df = df["obs_shear_stress"]
shear_stress_df.shape
# Out:
# (20000,)

# %%
SMOOTHING_WINDOW = 1
DOWNSAMPLING_FACTOR = 2
df_smoothed = moving_average_causal_filter(
    shear_stress_df, SMOOTHING_WINDOW, DOWNSAMPLING_FACTOR
)
df_smoothed.shape
# Out:
# (10000,)

# %%
results = compare_feature_statistics(shear_stress_df, df_smoothed)
results
# Out:
# {'mean_comparison': {'t_statistic': 0.003897796975239095,
#   'p_value': 0.9968900417656372,
#   'significant': False},
#  'variance_comparison': {'f_statistic': 1.5192821265099376e-05,
#   'p_value': 0.9968900419003165,
#   'significant': False}}

# %%
plot_original_vs_processed_data(
    shear_stress_df, df_smoothed, "line", "Downsampled"
)

# %%
import pandas as pd
from gluonts.dataset.pandas import PandasDataset
from gluonts.dataset.split import split
from gluonts.torch import TemporalFusionTransformerEstimator

LOOKBACK, FORECAST = 300, 30
N_FORECAST_WINDOWS = 60

ts_data = pd.DataFrame(df_smoothed)
dummy_idx = pd.date_range("2024-01-01", periods=len(ts_data), freq="S")
ts_data = ts_data.set_index(dummy_idx)
dataset = PandasDataset(ts_data, target="obs_shear_stress")

test_size = N_FORECAST_WINDOWS * FORECAST
train_size = len(ts_data) - test_size

training_data, test_gen = split(dataset, offset=-test_size)
test_data = test_gen.generate_instances(
    prediction_length=FORECAST, windows=N_FORECAST_WINDOWS
)

# %%
model = TemporalFusionTransformerEstimator(
    prediction_length=FORECAST,
    freq="S",
    context_length=LOOKBACK,
    trainer_kwargs={"max_epochs": 100, "devices": 1},
).train(training_data)
# Out:
# /home/users/p341cam/miniconda3/envs/venv/lib/python3.11/site-packages/lightning/fabric/plugins/environments/slurm.py:191: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /home/users/p341cam/miniconda3/envs/venv/lib/python3 ...
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /home/users/p341cam/miniconda3/envs/venv/lib/python3.11/site-packages/lightning/pytorch/trainer/configuration_validator.py:74: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
# You are using a CUDA device ('NVIDIA A100-SXM4-40GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name  | Type                           | Params | In sizes                                                                                 | Out sizes
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------
# 0 | model | TemporalFusionTransformerModel | 144 K  | [[1, 300], [1, 300], [1, 1], [1, 1], [1, 330, 6], [1, 330, 0], [1, 300, 0], [1, 300, 0]] | [1, 9, 30]
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------
# 144 K     Trainable params
# 0         Non-trainable params
# 144 K     Total params
# 0.576     Total estimated model params size (MB)
# Training: |                                      | 0/? [00:00<?, ?it/s]
# Epoch 0, global step 50: 'train_loss' reached 1.28423 (best 1.28423), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=0-step=50.ckpt' as top 1
# Epoch 1, global step 100: 'train_loss' reached 0.94776 (best 0.94776), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=1-step=100.ckpt' as top 1
# Epoch 2, global step 150: 'train_loss' reached 0.46269 (best 0.46269), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=2-step=150.ckpt' as top 1
# Epoch 3, global step 200: 'train_loss' reached 0.44297 (best 0.44297), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=3-step=200.ckpt' as top 1
# Epoch 4, global step 250: 'train_loss' reached 0.31792 (best 0.31792), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=4-step=250.ckpt' as top 1
# Epoch 5, global step 300: 'train_loss' was not in top 1
# Epoch 6, global step 350: 'train_loss' reached 0.28859 (best 0.28859), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=6-step=350.ckpt' as top 1
# Epoch 7, global step 400: 'train_loss' was not in top 1
# Epoch 8, global step 450: 'train_loss' was not in top 1
# Epoch 9, global step 500: 'train_loss' reached 0.28033 (best 0.28033), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=9-step=500.ckpt' as top 1
# Epoch 10, global step 550: 'train_loss' reached 0.25905 (best 0.25905), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=10-step=550.ckpt' as top 1
# Epoch 11, global step 600: 'train_loss' was not in top 1
# Epoch 12, global step 650: 'train_loss' was not in top 1
# Epoch 13, global step 700: 'train_loss' reached 0.25086 (best 0.25086), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=13-step=700.ckpt' as top 1
# Epoch 14, global step 750: 'train_loss' reached 0.23714 (best 0.23714), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=14-step=750.ckpt' as top 1
# Epoch 15, global step 800: 'train_loss' was not in top 1
# Epoch 16, global step 850: 'train_loss' reached 0.23152 (best 0.23152), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=16-step=850.ckpt' as top 1
# Epoch 17, global step 900: 'train_loss' reached 0.21392 (best 0.21392), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=17-step=900.ckpt' as top 1
# Epoch 18, global step 950: 'train_loss' reached 0.21169 (best 0.21169), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=18-step=950.ckpt' as top 1
# Epoch 19, global step 1000: 'train_loss' reached 0.19964 (best 0.19964), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=19-step=1000.ckpt' as top 1
# Epoch 20, global step 1050: 'train_loss' was not in top 1
# Epoch 21, global step 1100: 'train_loss' was not in top 1
# Epoch 22, global step 1150: 'train_loss' was not in top 1
# Epoch 23, global step 1200: 'train_loss' was not in top 1
# Epoch 24, global step 1250: 'train_loss' reached 0.17184 (best 0.17184), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=24-step=1250.ckpt' as top 1
# Epoch 25, global step 1300: 'train_loss' was not in top 1
# Epoch 26, global step 1350: 'train_loss' was not in top 1
# Epoch 27, global step 1400: 'train_loss' was not in top 1
# Epoch 28, global step 1450: 'train_loss' was not in top 1
# Epoch 29, global step 1500: 'train_loss' was not in top 1
# Epoch 30, global step 1550: 'train_loss' reached 0.16030 (best 0.16030), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=30-step=1550.ckpt' as top 1
# Epoch 31, global step 1600: 'train_loss' was not in top 1
# Epoch 32, global step 1650: 'train_loss' was not in top 1
# Epoch 33, global step 1700: 'train_loss' reached 0.15078 (best 0.15078), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=33-step=1700.ckpt' as top 1
# Epoch 34, global step 1750: 'train_loss' reached 0.13298 (best 0.13298), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=34-step=1750.ckpt' as top 1
# Epoch 35, global step 1800: 'train_loss' reached 0.12086 (best 0.12086), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=35-step=1800.ckpt' as top 1
# Epoch 36, global step 1850: 'train_loss' reached 0.11819 (best 0.11819), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=36-step=1850.ckpt' as top 1
# Epoch 37, global step 1900: 'train_loss' was not in top 1
# Epoch 38, global step 1950: 'train_loss' was not in top 1
# Epoch 39, global step 2000: 'train_loss' reached 0.11117 (best 0.11117), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=39-step=2000.ckpt' as top 1
# Epoch 40, global step 2050: 'train_loss' reached 0.10609 (best 0.10609), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=40-step=2050.ckpt' as top 1
# Epoch 41, global step 2100: 'train_loss' reached 0.10263 (best 0.10263), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=41-step=2100.ckpt' as top 1
# Epoch 42, global step 2150: 'train_loss' was not in top 1
# Epoch 43, global step 2200: 'train_loss' was not in top 1
# Epoch 44, global step 2250: 'train_loss' reached 0.09113 (best 0.09113), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=44-step=2250.ckpt' as top 1
# Epoch 45, global step 2300: 'train_loss' reached 0.08848 (best 0.08848), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=45-step=2300.ckpt' as top 1
# Epoch 46, global step 2350: 'train_loss' was not in top 1
# Epoch 47, global step 2400: 'train_loss' was not in top 1
# Epoch 48, global step 2450: 'train_loss' reached 0.08752 (best 0.08752), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=48-step=2450.ckpt' as top 1
# Epoch 49, global step 2500: 'train_loss' reached 0.08699 (best 0.08699), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=49-step=2500.ckpt' as top 1
# Epoch 50, global step 2550: 'train_loss' reached 0.08326 (best 0.08326), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=50-step=2550.ckpt' as top 1
# Epoch 51, global step 2600: 'train_loss' reached 0.06984 (best 0.06984), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=51-step=2600.ckpt' as top 1
# Epoch 52, global step 2650: 'train_loss' was not in top 1
# Epoch 53, global step 2700: 'train_loss' was not in top 1
# Epoch 54, global step 2750: 'train_loss' was not in top 1
# Epoch 55, global step 2800: 'train_loss' was not in top 1
# Epoch 56, global step 2850: 'train_loss' was not in top 1
# Epoch 57, global step 2900: 'train_loss' reached 0.06877 (best 0.06877), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=57-step=2900.ckpt' as top 1
# Epoch 58, global step 2950: 'train_loss' reached 0.06765 (best 0.06765), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=58-step=2950.ckpt' as top 1
# Epoch 59, global step 3000: 'train_loss' was not in top 1
# Epoch 60, global step 3050: 'train_loss' was not in top 1
# Epoch 61, global step 3100: 'train_loss' was not in top 1
# Epoch 62, global step 3150: 'train_loss' was not in top 1
# Epoch 63, global step 3200: 'train_loss' was not in top 1
# Epoch 64, global step 3250: 'train_loss' reached 0.06446 (best 0.06446), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=64-step=3250.ckpt' as top 1
# Epoch 65, global step 3300: 'train_loss' was not in top 1
# Epoch 66, global step 3350: 'train_loss' was not in top 1
# Epoch 67, global step 3400: 'train_loss' reached 0.05836 (best 0.05836), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=67-step=3400.ckpt' as top 1
# Epoch 68, global step 3450: 'train_loss' was not in top 1
# Epoch 69, global step 3500: 'train_loss' was not in top 1
# Epoch 70, global step 3550: 'train_loss' was not in top 1
# Epoch 71, global step 3600: 'train_loss' was not in top 1
# Epoch 72, global step 3650: 'train_loss' was not in top 1
# Epoch 73, global step 3700: 'train_loss' reached 0.05806 (best 0.05806), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=73-step=3700.ckpt' as top 1
# Epoch 74, global step 3750: 'train_loss' reached 0.05729 (best 0.05729), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=74-step=3750.ckpt' as top 1
# Epoch 75, global step 3800: 'train_loss' was not in top 1
# Epoch 76, global step 3850: 'train_loss' was not in top 1
# Epoch 77, global step 3900: 'train_loss' was not in top 1
# Epoch 78, global step 3950: 'train_loss' was not in top 1
# Epoch 79, global step 4000: 'train_loss' was not in top 1
# Epoch 80, global step 4050: 'train_loss' reached 0.05666 (best 0.05666), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=80-step=4050.ckpt' as top 1
# Epoch 81, global step 4100: 'train_loss' was not in top 1
# Epoch 82, global step 4150: 'train_loss' reached 0.05052 (best 0.05052), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=82-step=4150.ckpt' as top 1
# Epoch 83, global step 4200: 'train_loss' was not in top 1
# Epoch 84, global step 4250: 'train_loss' was not in top 1
# Epoch 85, global step 4300: 'train_loss' was not in top 1
# Epoch 86, global step 4350: 'train_loss' was not in top 1
# Epoch 87, global step 4400: 'train_loss' was not in top 1
# Epoch 88, global step 4450: 'train_loss' was not in top 1
# Epoch 89, global step 4500: 'train_loss' was not in top 1
# Epoch 90, global step 4550: 'train_loss' was not in top 1
# Epoch 91, global step 4600: 'train_loss' was not in top 1
# Epoch 92, global step 4650: 'train_loss' was not in top 1
# Epoch 93, global step 4700: 'train_loss' was not in top 1
# Epoch 94, global step 4750: 'train_loss' reached 0.04505 (best 0.04505), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=94-step=4750.ckpt' as top 1
# Epoch 95, global step 4800: 'train_loss' reached 0.04164 (best 0.04164), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=95-step=4800.ckpt' as top 1
# Epoch 96, global step 4850: 'train_loss' was not in top 1
# Epoch 97, global step 4900: 'train_loss' reached 0.03906 (best 0.03906), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=97-step=4900.ckpt' as top 1
# Epoch 98, global step 4950: 'train_loss' was not in top 1
# Epoch 99, global step 5000: 'train_loss' reached 0.03795 (best 0.03795), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_37/checkpoints/epoch=99-step=5000.ckpt' as top 1
# `Trainer.fit` stopped: `max_epochs=100` reached.

# %%
from sklearn.metrics import mean_squared_error, r2_score

fcast = list(model.predict(test_data.input))
test_outputs = np.array([x["0.5"] for x in fcast]).reshape(-1)
test_iqr = np.array([0.5 * (x["0.9"] - x["0.1"]) for x in fcast]).reshape(-1)
test_rmse = np.sqrt(
    mean_squared_error(
        test_outputs, ts_data.iloc[train_size:]["obs_shear_stress"].values
    )
)

test_r2 = r2_score(
    test_outputs, ts_data.iloc[train_size:]["obs_shear_stress"].values
)
print(f"Test RMSE: {test_rmse:.4f}, Test R^2: {test_r2:.4f}")
# Out:
# Test RMSE: 0.0119, Test R^2: 0.9969

# %%
train_outputs = np.array([[np.nan] for x in range(train_size)]).reshape(-1)
train_iqr = np.array([[np.nan] for x in range(train_size)]).reshape(-1)

all_outputs = np.concatenate((train_outputs, test_outputs))
all_iqr = np.concatenate((train_iqr, test_iqr))

test_start_index = len(ts_data) - test_size - LOOKBACK

plt.plot(ts_data["obs_shear_stress"].values, label="True values")
plt.plot(
    range(0, len(all_outputs)),
    all_outputs,
    label=r"Forecasts $\pm$ IQR",
)
plt.fill_between(
    range(0, len(all_outputs)),
    all_outputs - all_iqr,
    all_outputs + all_iqr,
    alpha=0.3,
    facecolor="#FF9848",
)

plt.axvline(
    x=test_start_index, color="gray", linestyle="--", label="Test set start"
)
plt.xlabel("Time")
plt.ylabel("Value")
plt.legend()
plt.title("TFT Forecasts vs True Values")
plt.show()

# %%
plt.plot(ts_data["obs_shear_stress"].values[-test_size:], label="True values")
plt.plot(
    range(test_size),
    test_outputs,
    label=r"Forecasts $\pm$ IQR",
)

plt.fill_between(
    range(0, test_size),
    test_outputs - test_iqr,
    test_outputs + test_iqr,
    alpha=0.3,
    facecolor="#FF9848",
)

plt.xlabel("Time")
plt.ylabel("Value")
plt.legend()
plt.title("TFT Forecasts vs True Values")
plt.show()

# %%
###### Lab data training #########

# %%
set_seed(SEED)

device = set_torch_device()
# Out:
# GPU name: NVIDIA A100-SXM4-40GB
# Max GPU memory: 42.297786368 GiB

# %%
EXP = "b698"

dataset = SlowEarthquakeDataset([EXP])
df = SlowEarthquakeDataset.convert_to_df(dataset, EXP)

df.head()
# Out:
#    obs_shear_stress  obs_normal_stress  obs_ecdisp  obs_shear_strain  time
# 0         11.225116          17.382861   20.088637         22.167371  0.00
# 1         11.222870          17.375571   20.088683         22.167447  0.01
# 2         11.224972          17.385328   20.088975         22.167941  0.02
# 3         11.221124          17.373017   20.088549         22.167221  0.03
# 4         11.225461          17.386512   20.089116         22.168180  0.04

# %%
shear_stress_df = df["obs_shear_stress"]
shear_stress_df.shape
# Out:
# (20001,)

# %%
SMOOTHING_WINDOW = 1
DOWNSAMPLING_FACTOR = 2
df_smoothed = moving_average_causal_filter(
    shear_stress_df, SMOOTHING_WINDOW, DOWNSAMPLING_FACTOR
)
df_smoothed.shape
# Out:
# (10001,)

# %%
results = compare_feature_statistics(shear_stress_df, df_smoothed)
results
# Out:
# {'mean_comparison': {'t_statistic': 0.01129208583655751,
#   'p_value': 0.9909904856087365,
#   'significant': False},
#  'variance_comparison': {'f_statistic': 0.00012751120251926028,
#   'p_value': 0.9909904856229135,
#   'significant': False}}

# %%
plot_original_vs_processed_data(
    shear_stress_df, df_smoothed, "line", "Downsampled"
)

# %%
plot_original_vs_processed_data(
    shear_stress_df, df_smoothed, "scatter", "Downsampled"
)

# %%
ts_data = pd.DataFrame(df_smoothed)
dummy_idx = pd.date_range("2024-01-01", periods=len(ts_data), freq="S")
ts_data = ts_data.set_index(dummy_idx)
dataset = PandasDataset(ts_data, target="obs_shear_stress")

test_size = N_FORECAST_WINDOWS * FORECAST
train_size = len(ts_data) - test_size

training_data, test_gen = split(dataset, offset=-test_size)
test_data = test_gen.generate_instances(
    prediction_length=FORECAST, windows=N_FORECAST_WINDOWS
)

# %%
estimator = TemporalFusionTransformerEstimator(
    prediction_length=FORECAST,
    freq="S",
    context_length=LOOKBACK,
    trainer_kwargs={"max_epochs": 100, "devices": 1},
)

model_lab = estimator.train_model(training_data, from_predictor=model)
# Out:
# /home/users/p341cam/miniconda3/envs/venv/lib/python3.11/site-packages/lightning/fabric/plugins/environments/slurm.py:191: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /home/users/p341cam/miniconda3/envs/venv/lib/python3 ...
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /home/users/p341cam/miniconda3/envs/venv/lib/python3.11/site-packages/lightning/pytorch/trainer/configuration_validator.py:74: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name  | Type                           | Params | In sizes                                                                                 | Out sizes
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------
# 0 | model | TemporalFusionTransformerModel | 144 K  | [[1, 300], [1, 300], [1, 1], [1, 1], [1, 330, 6], [1, 330, 0], [1, 300, 0], [1, 300, 0]] | [1, 9, 30]
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------
# 144 K     Trainable params
# 0         Non-trainable params
# 144 K     Total params
# 0.576     Total estimated model params size (MB)
# Training: |                                      | 0/? [00:00<?, ?it/s]
# Epoch 0, global step 50: 'train_loss' reached 0.22891 (best 0.22891), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_39/checkpoints/epoch=0-step=50.ckpt' as top 1
# Epoch 1, global step 100: 'train_loss' reached 0.20281 (best 0.20281), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_39/checkpoints/epoch=1-step=100.ckpt' as top 1
# Epoch 2, global step 150: 'train_loss' reached 0.19239 (best 0.19239), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_39/checkpoints/epoch=2-step=150.ckpt' as top 1
# Epoch 3, global step 200: 'train_loss' was not in top 1
# Epoch 4, global step 250: 'train_loss' reached 0.14001 (best 0.14001), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_39/checkpoints/epoch=4-step=250.ckpt' as top 1
# Epoch 5, global step 300: 'train_loss' was not in top 1
# Epoch 6, global step 350: 'train_loss' reached 0.13086 (best 0.13086), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_39/checkpoints/epoch=6-step=350.ckpt' as top 1
# Epoch 7, global step 400: 'train_loss' reached 0.11598 (best 0.11598), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_39/checkpoints/epoch=7-step=400.ckpt' as top 1
# Epoch 8, global step 450: 'train_loss' reached 0.10112 (best 0.10112), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_39/checkpoints/epoch=8-step=450.ckpt' as top 1
# Epoch 9, global step 500: 'train_loss' was not in top 1
# Epoch 10, global step 550: 'train_loss' was not in top 1
# Epoch 11, global step 600: 'train_loss' was not in top 1
# Epoch 12, global step 650: 'train_loss' was not in top 1
# Epoch 13, global step 700: 'train_loss' was not in top 1
# Epoch 14, global step 750: 'train_loss' was not in top 1
# Epoch 15, global step 800: 'train_loss' reached 0.08721 (best 0.08721), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_39/checkpoints/epoch=15-step=800.ckpt' as top 1
# Epoch 16, global step 850: 'train_loss' was not in top 1
# Epoch 17, global step 900: 'train_loss' was not in top 1
# Epoch 18, global step 950: 'train_loss' was not in top 1
# Epoch 19, global step 1000: 'train_loss' was not in top 1
# Epoch 20, global step 1050: 'train_loss' was not in top 1
# Epoch 21, global step 1100: 'train_loss' was not in top 1
# Epoch 22, global step 1150: 'train_loss' was not in top 1
# Epoch 23, global step 1200: 'train_loss' was not in top 1
# Epoch 24, global step 1250: 'train_loss' was not in top 1
# Epoch 25, global step 1300: 'train_loss' was not in top 1
# Epoch 26, global step 1350: 'train_loss' was not in top 1
# Epoch 27, global step 1400: 'train_loss' reached 0.08210 (best 0.08210), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_39/checkpoints/epoch=27-step=1400.ckpt' as top 1
# Epoch 28, global step 1450: 'train_loss' reached 0.07828 (best 0.07828), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_39/checkpoints/epoch=28-step=1450.ckpt' as top 1
# Epoch 29, global step 1500: 'train_loss' reached 0.07803 (best 0.07803), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_39/checkpoints/epoch=29-step=1500.ckpt' as top 1
# Epoch 30, global step 1550: 'train_loss' reached 0.07598 (best 0.07598), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_39/checkpoints/epoch=30-step=1550.ckpt' as top 1
# Epoch 31, global step 1600: 'train_loss' reached 0.07419 (best 0.07419), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_39/checkpoints/epoch=31-step=1600.ckpt' as top 1
# Epoch 32, global step 1650: 'train_loss' reached 0.07147 (best 0.07147), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_39/checkpoints/epoch=32-step=1650.ckpt' as top 1
# Epoch 33, global step 1700: 'train_loss' was not in top 1
# Epoch 34, global step 1750: 'train_loss' was not in top 1
# Epoch 35, global step 1800: 'train_loss' was not in top 1
# Epoch 36, global step 1850: 'train_loss' was not in top 1
# Epoch 37, global step 1900: 'train_loss' was not in top 1
# Epoch 38, global step 1950: 'train_loss' was not in top 1
# Epoch 39, global step 2000: 'train_loss' was not in top 1
# Epoch 40, global step 2050: 'train_loss' was not in top 1
# Epoch 41, global step 2100: 'train_loss' reached 0.06743 (best 0.06743), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_39/checkpoints/epoch=41-step=2100.ckpt' as top 1
# Epoch 42, global step 2150: 'train_loss' was not in top 1
# Epoch 43, global step 2200: 'train_loss' was not in top 1
# Epoch 44, global step 2250: 'train_loss' was not in top 1
# Epoch 45, global step 2300: 'train_loss' was not in top 1
# Epoch 46, global step 2350: 'train_loss' was not in top 1
# Epoch 47, global step 2400: 'train_loss' was not in top 1
# Epoch 48, global step 2450: 'train_loss' was not in top 1
# Epoch 49, global step 2500: 'train_loss' was not in top 1
# Epoch 50, global step 2550: 'train_loss' was not in top 1
# Epoch 51, global step 2600: 'train_loss' was not in top 1
# Epoch 52, global step 2650: 'train_loss' was not in top 1
# Epoch 53, global step 2700: 'train_loss' was not in top 1
# Epoch 54, global step 2750: 'train_loss' reached 0.06433 (best 0.06433), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_39/checkpoints/epoch=54-step=2750.ckpt' as top 1
# Epoch 55, global step 2800: 'train_loss' was not in top 1
# Epoch 56, global step 2850: 'train_loss' was not in top 1
# Epoch 57, global step 2900: 'train_loss' was not in top 1
# Epoch 58, global step 2950: 'train_loss' was not in top 1
# Epoch 59, global step 3000: 'train_loss' was not in top 1
# Epoch 60, global step 3050: 'train_loss' was not in top 1
# Epoch 61, global step 3100: 'train_loss' was not in top 1
# Epoch 62, global step 3150: 'train_loss' was not in top 1
# Epoch 63, global step 3200: 'train_loss' was not in top 1
# Epoch 64, global step 3250: 'train_loss' was not in top 1
# Epoch 65, global step 3300: 'train_loss' reached 0.06406 (best 0.06406), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_39/checkpoints/epoch=65-step=3300.ckpt' as top 1
# Epoch 66, global step 3350: 'train_loss' was not in top 1
# Epoch 67, global step 3400: 'train_loss' was not in top 1
# Epoch 68, global step 3450: 'train_loss' reached 0.06296 (best 0.06296), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_39/checkpoints/epoch=68-step=3450.ckpt' as top 1
# Epoch 69, global step 3500: 'train_loss' was not in top 1
# Epoch 70, global step 3550: 'train_loss' was not in top 1
# Epoch 71, global step 3600: 'train_loss' was not in top 1
# Epoch 72, global step 3650: 'train_loss' reached 0.05934 (best 0.05934), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_39/checkpoints/epoch=72-step=3650.ckpt' as top 1
# Epoch 73, global step 3700: 'train_loss' was not in top 1
# Epoch 74, global step 3750: 'train_loss' was not in top 1
# Epoch 75, global step 3800: 'train_loss' was not in top 1
# Epoch 76, global step 3850: 'train_loss' was not in top 1
# Epoch 77, global step 3900: 'train_loss' was not in top 1
# Epoch 78, global step 3950: 'train_loss' was not in top 1
# Epoch 79, global step 4000: 'train_loss' was not in top 1
# Epoch 80, global step 4050: 'train_loss' was not in top 1
# Epoch 81, global step 4100: 'train_loss' was not in top 1
# Epoch 82, global step 4150: 'train_loss' was not in top 1
# Epoch 83, global step 4200: 'train_loss' was not in top 1
# Epoch 84, global step 4250: 'train_loss' was not in top 1
# Epoch 85, global step 4300: 'train_loss' was not in top 1
# Epoch 86, global step 4350: 'train_loss' was not in top 1
# Epoch 87, global step 4400: 'train_loss' was not in top 1
# Epoch 88, global step 4450: 'train_loss' reached 0.05934 (best 0.05934), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_39/checkpoints/epoch=88-step=4450.ckpt' as top 1
# Epoch 89, global step 4500: 'train_loss' reached 0.05713 (best 0.05713), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_39/checkpoints/epoch=89-step=4500.ckpt' as top 1
# Epoch 90, global step 4550: 'train_loss' was not in top 1
# Epoch 91, global step 4600: 'train_loss' was not in top 1
# Epoch 92, global step 4650: 'train_loss' was not in top 1
# Epoch 93, global step 4700: 'train_loss' reached 0.05687 (best 0.05687), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_39/checkpoints/epoch=93-step=4700.ckpt' as top 1
# Epoch 94, global step 4750: 'train_loss' was not in top 1
# Epoch 95, global step 4800: 'train_loss' reached 0.05425 (best 0.05425), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_39/checkpoints/epoch=95-step=4800.ckpt' as top 1
# Epoch 96, global step 4850: 'train_loss' was not in top 1
# Epoch 97, global step 4900: 'train_loss' was not in top 1
# Epoch 98, global step 4950: 'train_loss' was not in top 1
# Epoch 99, global step 5000: 'train_loss' was not in top 1
# `Trainer.fit` stopped: `max_epochs=100` reached.

# %%
from sklearn.metrics import mean_squared_error, r2_score

fcast = list(model.predictor.predict(test_data.input))
test_outputs = np.array([x["0.5"] for x in fcast]).reshape(-1)
test_iqr = np.array([0.5 * (x["0.9"] - x["0.1"]) for x in fcast]).reshape(-1)
test_rmse = np.sqrt(
    mean_squared_error(
        test_outputs, ts_data.iloc[train_size:]["obs_shear_stress"].values
    )
)

test_r2 = r2_score(
    test_outputs, ts_data.iloc[train_size:]["obs_shear_stress"].values
)
print(f"Test RMSE: {test_rmse:.4f}, Test R^2: {test_r2:.4f}")
# Out:
# Test RMSE: 0.0327, Test R^2: 0.9535

# %%
train_outputs = np.array([[np.nan] for x in range(train_size)]).reshape(-1)
train_iqr = np.array([[np.nan] for x in range(train_size)]).reshape(-1)

all_outputs = np.concatenate((train_outputs, test_outputs))
all_iqr = np.concatenate((train_iqr, test_iqr))

test_start_index = len(ts_data) - test_size - LOOKBACK

plt.plot(ts_data["obs_shear_stress"].values, label="True values")
plt.plot(
    range(0, len(all_outputs)),
    all_outputs,
    label=r"Forecasts $\pm$ IQR",
)
plt.fill_between(
    range(0, len(all_outputs)),
    all_outputs - all_iqr,
    all_outputs + all_iqr,
    alpha=0.3,
    facecolor="#FF9848",
)

plt.axvline(
    x=test_start_index, color="gray", linestyle="--", label="Test set start"
)
plt.xlabel("Time")
plt.ylabel("Value")
plt.legend()
plt.title("TFT Forecasts vs True Values")
plt.show()

# %%
plt.plot(ts_data["obs_shear_stress"].values[-test_size:], label="True values")
plt.plot(
    range(test_size),
    test_outputs,
    label=r"Forecasts $\pm$ IQR",
)

plt.fill_between(
    range(0, test_size),
    test_outputs - test_iqr,
    test_outputs + test_iqr,
    alpha=0.3,
    facecolor="#FF9848",
)

plt.xlabel("Time")
plt.ylabel("Value")
plt.legend()
plt.title("TFT Forecasts vs True Values")
plt.show()

# %%
###### Regular Lab data training #########

# %%
set_seed(SEED)

device = set_torch_device()
# Out:
# GPU name: NVIDIA A100-SXM4-40GB
# Max GPU memory: 42.297786368 GiB

# %%
model = TemporalFusionTransformerEstimator(
    prediction_length=FORECAST,
    freq="S",
    context_length=LOOKBACK,
    trainer_kwargs={"max_epochs": 100, "devices": 1},
).train(training_data)
# Out:
# /home/users/p341cam/miniconda3/envs/venv/lib/python3.11/site-packages/lightning/fabric/plugins/environments/slurm.py:191: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /home/users/p341cam/miniconda3/envs/venv/lib/python3 ...
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /home/users/p341cam/miniconda3/envs/venv/lib/python3.11/site-packages/lightning/pytorch/trainer/configuration_validator.py:74: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name  | Type                           | Params | In sizes                                                                                 | Out sizes
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------
# 0 | model | TemporalFusionTransformerModel | 144 K  | [[1, 300], [1, 300], [1, 1], [1, 1], [1, 330, 6], [1, 330, 0], [1, 300, 0], [1, 300, 0]] | [1, 9, 30]
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------
# 144 K     Trainable params
# 0         Non-trainable params
# 144 K     Total params
# 0.576     Total estimated model params size (MB)
# Training: |                                      | 0/? [00:00<?, ?it/s]
# Epoch 0, global step 50: 'train_loss' reached 0.96854 (best 0.96854), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=0-step=50.ckpt' as top 1
# Epoch 1, global step 100: 'train_loss' reached 0.78420 (best 0.78420), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=1-step=100.ckpt' as top 1
# Epoch 2, global step 150: 'train_loss' reached 0.39332 (best 0.39332), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=2-step=150.ckpt' as top 1
# Epoch 3, global step 200: 'train_loss' reached 0.30964 (best 0.30964), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=3-step=200.ckpt' as top 1
# Epoch 4, global step 250: 'train_loss' reached 0.24704 (best 0.24704), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=4-step=250.ckpt' as top 1
# Epoch 5, global step 300: 'train_loss' reached 0.24361 (best 0.24361), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=5-step=300.ckpt' as top 1
# Epoch 6, global step 350: 'train_loss' was not in top 1
# Epoch 7, global step 400: 'train_loss' reached 0.21588 (best 0.21588), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=7-step=400.ckpt' as top 1
# Epoch 8, global step 450: 'train_loss' was not in top 1
# Epoch 9, global step 500: 'train_loss' reached 0.18388 (best 0.18388), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=9-step=500.ckpt' as top 1
# Epoch 10, global step 550: 'train_loss' reached 0.16875 (best 0.16875), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=10-step=550.ckpt' as top 1
# Epoch 11, global step 600: 'train_loss' reached 0.16608 (best 0.16608), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=11-step=600.ckpt' as top 1
# Epoch 12, global step 650: 'train_loss' reached 0.16006 (best 0.16006), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=12-step=650.ckpt' as top 1
# Epoch 13, global step 700: 'train_loss' was not in top 1
# Epoch 14, global step 750: 'train_loss' was not in top 1
# Epoch 15, global step 800: 'train_loss' reached 0.15843 (best 0.15843), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=15-step=800.ckpt' as top 1
# Epoch 16, global step 850: 'train_loss' reached 0.13959 (best 0.13959), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=16-step=850.ckpt' as top 1
# Epoch 17, global step 900: 'train_loss' was not in top 1
# Epoch 18, global step 950: 'train_loss' reached 0.13792 (best 0.13792), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=18-step=950.ckpt' as top 1
# Epoch 19, global step 1000: 'train_loss' reached 0.13648 (best 0.13648), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=19-step=1000.ckpt' as top 1
# Epoch 20, global step 1050: 'train_loss' was not in top 1
# Epoch 21, global step 1100: 'train_loss' was not in top 1
# Epoch 22, global step 1150: 'train_loss' was not in top 1
# Epoch 23, global step 1200: 'train_loss' was not in top 1
# Epoch 24, global step 1250: 'train_loss' reached 0.13056 (best 0.13056), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=24-step=1250.ckpt' as top 1
# Epoch 25, global step 1300: 'train_loss' was not in top 1
# Epoch 26, global step 1350: 'train_loss' was not in top 1
# Epoch 27, global step 1400: 'train_loss' was not in top 1
# Epoch 28, global step 1450: 'train_loss' reached 0.11834 (best 0.11834), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=28-step=1450.ckpt' as top 1
# Epoch 29, global step 1500: 'train_loss' was not in top 1
# Epoch 30, global step 1550: 'train_loss' was not in top 1
# Epoch 31, global step 1600: 'train_loss' was not in top 1
# Epoch 32, global step 1650: 'train_loss' was not in top 1
# Epoch 33, global step 1700: 'train_loss' was not in top 1
# Epoch 34, global step 1750: 'train_loss' was not in top 1
# Epoch 35, global step 1800: 'train_loss' reached 0.11531 (best 0.11531), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=35-step=1800.ckpt' as top 1
# Epoch 36, global step 1850: 'train_loss' was not in top 1
# Epoch 37, global step 1900: 'train_loss' was not in top 1
# Epoch 38, global step 1950: 'train_loss' was not in top 1
# Epoch 39, global step 2000: 'train_loss' was not in top 1
# Epoch 40, global step 2050: 'train_loss' was not in top 1
# Epoch 41, global step 2100: 'train_loss' was not in top 1
# Epoch 42, global step 2150: 'train_loss' was not in top 1
# Epoch 43, global step 2200: 'train_loss' reached 0.11116 (best 0.11116), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=43-step=2200.ckpt' as top 1
# Epoch 44, global step 2250: 'train_loss' was not in top 1
# Epoch 45, global step 2300: 'train_loss' was not in top 1
# Epoch 46, global step 2350: 'train_loss' reached 0.11072 (best 0.11072), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=46-step=2350.ckpt' as top 1
# Epoch 47, global step 2400: 'train_loss' reached 0.10374 (best 0.10374), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=47-step=2400.ckpt' as top 1
# Epoch 48, global step 2450: 'train_loss' was not in top 1
# Epoch 49, global step 2500: 'train_loss' reached 0.10008 (best 0.10008), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=49-step=2500.ckpt' as top 1
# Epoch 50, global step 2550: 'train_loss' was not in top 1
# Epoch 51, global step 2600: 'train_loss' was not in top 1
# Epoch 52, global step 2650: 'train_loss' was not in top 1
# Epoch 53, global step 2700: 'train_loss' reached 0.09189 (best 0.09189), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=53-step=2700.ckpt' as top 1
# Epoch 54, global step 2750: 'train_loss' was not in top 1
# Epoch 55, global step 2800: 'train_loss' was not in top 1
# Epoch 56, global step 2850: 'train_loss' was not in top 1
# Epoch 57, global step 2900: 'train_loss' was not in top 1
# Epoch 58, global step 2950: 'train_loss' was not in top 1
# Epoch 59, global step 3000: 'train_loss' was not in top 1
# Epoch 60, global step 3050: 'train_loss' was not in top 1
# Epoch 61, global step 3100: 'train_loss' was not in top 1
# Epoch 62, global step 3150: 'train_loss' was not in top 1
# Epoch 63, global step 3200: 'train_loss' was not in top 1
# Epoch 64, global step 3250: 'train_loss' was not in top 1
# Epoch 65, global step 3300: 'train_loss' reached 0.07992 (best 0.07992), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=65-step=3300.ckpt' as top 1
# Epoch 66, global step 3350: 'train_loss' was not in top 1
# Epoch 67, global step 3400: 'train_loss' was not in top 1
# Epoch 68, global step 3450: 'train_loss' was not in top 1
# Epoch 69, global step 3500: 'train_loss' was not in top 1
# Epoch 70, global step 3550: 'train_loss' was not in top 1
# Epoch 71, global step 3600: 'train_loss' reached 0.07985 (best 0.07985), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=71-step=3600.ckpt' as top 1
# Epoch 72, global step 3650: 'train_loss' was not in top 1
# Epoch 73, global step 3700: 'train_loss' was not in top 1
# Epoch 74, global step 3750: 'train_loss' was not in top 1
# Epoch 75, global step 3800: 'train_loss' reached 0.07404 (best 0.07404), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=75-step=3800.ckpt' as top 1
# Epoch 76, global step 3850: 'train_loss' was not in top 1
# Epoch 77, global step 3900: 'train_loss' was not in top 1
# Epoch 78, global step 3950: 'train_loss' was not in top 1
# Epoch 79, global step 4000: 'train_loss' was not in top 1
# Epoch 80, global step 4050: 'train_loss' was not in top 1
# Epoch 81, global step 4100: 'train_loss' was not in top 1
# Epoch 82, global step 4150: 'train_loss' was not in top 1
# Epoch 83, global step 4200: 'train_loss' was not in top 1
# Epoch 84, global step 4250: 'train_loss' was not in top 1
# Epoch 85, global step 4300: 'train_loss' was not in top 1
# Epoch 86, global step 4350: 'train_loss' was not in top 1
# Epoch 87, global step 4400: 'train_loss' was not in top 1
# Epoch 88, global step 4450: 'train_loss' was not in top 1
# Epoch 89, global step 4500: 'train_loss' reached 0.07314 (best 0.07314), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=89-step=4500.ckpt' as top 1
# Epoch 90, global step 4550: 'train_loss' was not in top 1
# Epoch 91, global step 4600: 'train_loss' reached 0.07252 (best 0.07252), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=91-step=4600.ckpt' as top 1
# Epoch 92, global step 4650: 'train_loss' was not in top 1
# Epoch 93, global step 4700: 'train_loss' reached 0.06775 (best 0.06775), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=93-step=4700.ckpt' as top 1
# Epoch 94, global step 4750: 'train_loss' was not in top 1
# Epoch 95, global step 4800: 'train_loss' was not in top 1
# Epoch 96, global step 4850: 'train_loss' reached 0.06654 (best 0.06654), saving model to '/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/notebooks/lightning_logs/version_40/checkpoints/epoch=96-step=4850.ckpt' as top 1
# Epoch 97, global step 4900: 'train_loss' was not in top 1
# Epoch 98, global step 4950: 'train_loss' was not in top 1
# Epoch 99, global step 5000: 'train_loss' was not in top 1
# `Trainer.fit` stopped: `max_epochs=100` reached.

# %%
from sklearn.metrics import mean_squared_error, r2_score

fcast = list(model.predict(test_data.input))
test_outputs = np.array([x["0.5"] for x in fcast]).reshape(-1)
test_iqr = np.array([0.5 * (x["0.9"] - x["0.1"]) for x in fcast]).reshape(-1)
test_rmse = np.sqrt(
    mean_squared_error(
        test_outputs, ts_data.iloc[train_size:]["obs_shear_stress"].values
    )
)

test_r2 = r2_score(
    test_outputs, ts_data.iloc[train_size:]["obs_shear_stress"].values
)
print(f"Test RMSE: {test_rmse:.4f}, Test R^2: {test_r2:.4f}")
# Out:
# Test RMSE: 0.0423, Test R^2: 0.9173

# %%
train_outputs = np.array([[np.nan] for x in range(train_size)]).reshape(-1)
train_iqr = np.array([[np.nan] for x in range(train_size)]).reshape(-1)

all_outputs = np.concatenate((train_outputs, test_outputs))
all_iqr = np.concatenate((train_iqr, test_iqr))

test_start_index = len(ts_data) - test_size - LOOKBACK

plt.plot(ts_data["obs_shear_stress"].values, label="True values")
plt.plot(
    range(0, len(all_outputs)),
    all_outputs,
    label=r"Forecasts $\pm$ IQR",
)
plt.fill_between(
    range(0, len(all_outputs)),
    all_outputs - all_iqr,
    all_outputs + all_iqr,
    alpha=0.3,
    facecolor="#FF9848",
)

plt.axvline(
    x=test_start_index, color="gray", linestyle="--", label="Test set start"
)
plt.xlabel("Time")
plt.ylabel("Value")
plt.legend()
plt.title("TFT Forecasts vs True Values")
plt.show()

# %%
plt.plot(ts_data["obs_shear_stress"].values[-test_size:], label="True values")
plt.plot(
    range(test_size),
    test_outputs,
    label=r"Forecasts $\pm$ IQR",
)

plt.fill_between(
    range(0, test_size),
    test_outputs - test_iqr,
    test_outputs + test_iqr,
    alpha=0.3,
    facecolor="#FF9848",
)

plt.xlabel("Time")
plt.ylabel("Value")
plt.legend()
plt.title("TFT Forecasts vs True Values")
plt.show()
