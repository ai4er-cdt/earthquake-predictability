# %%
import matplotlib.pyplot as plt
import numpy as np

import scripts.models.tcn_oneshot_multistep as tcn
from utils.data_preprocessing import (
    compare_feature_statistics,
    create_dataset,
    moving_average_causal_filter,
    normalise_dataset,
    split_train_test_forecast_windows,
)
from utils.dataset import SlowEarthquakeDataset
from utils.general_functions import set_seed, set_torch_device
from utils.nn_io import load_model
from utils.nn_train import eval_model_on_test_set, train_model
from utils.plotting import (
    plot_all_data_results,
    plot_metric_results,
    plot_original_vs_processed_data,
)

# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import json

with open("../conf.json", "r") as f:
    config = json.load(f)

# %%
###### Simulated data training #########

# %%
SEED = 42
set_seed(SEED)

device = set_torch_device()
# Out:
# GPU name: NVIDIA A100-SXM4-40GB
# Max GPU memory: 42.297786368 GiB

# %%
EXP = "sim_b698"

dataset = SlowEarthquakeDataset([EXP])
df = SlowEarthquakeDataset.convert_to_df(dataset, EXP)

df.head()
# Out:
#    obs_shear_stress  obs_normal_stress  time
# 0         10.656969          16.801851  0.00
# 1         10.658275          16.802265  0.01
# 2         10.659582          16.802679  0.02
# 3         10.660889          16.803091  0.03
# 4         10.662196          16.803503  0.04

# %%
shear_stress_df = df["obs_shear_stress"]
shear_stress_df.shape
# Out:
# (20000,)

# %%
SMOOTHING_WINDOW = config[EXP]["smoothing_window"]
DOWNSAMPLING_FACTOR = config[EXP]["downsampling_factor"]
df_smoothed = moving_average_causal_filter(
    shear_stress_df, SMOOTHING_WINDOW, DOWNSAMPLING_FACTOR
)
df_smoothed.shape
# Out:
# (9999,)

# %%
results = compare_feature_statistics(shear_stress_df, df_smoothed)
results
# Out:
# {'mean_comparison': {'t_statistic': -0.005411611278037008,
#   'p_value': 0.9956822159731284,
#   'significant': False},
#  'variance_comparison': {'f_statistic': 2.9285536623976996e-05,
#   'p_value': 0.995682216006686,
#   'significant': False}}

# %%
plot_original_vs_processed_data(
    shear_stress_df, df_smoothed, "line", "Downsampled"
)

# %%
plot_original_vs_processed_data(
    shear_stress_df, df_smoothed, "scatter", "Downsampled"
)

# %%
OPTUNA_PARAMS_PATH = "/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/scripts/optuna_results/p341cam_best_TCN_sim_b698_2024-03-05T15:46:50.csv"
MODEL_DIR = "/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/results/p341cam_TCN_sim_b698_2024-03-05T15:46:48_torch"

import csv

reader = csv.reader(open(OPTUNA_PARAMS_PATH, "r"))
optuna_params = {}
for row in reader:
    k, v = row
    optuna_params[k] = v

optuna_params
# Out:
# {'lookback': '277',
#  'hidden_size': '16',
#  'kernel_size': '5',
#  'dropout': '0.35757708080044703'}

# %%
LOOKBACK, FORECAST = int(optuna_params["lookback"]), 30
N_FORECAST_WINDOWS = 15
N_VALIDATION_WINDOWS = 15

X, y = create_dataset(df_smoothed, LOOKBACK, FORECAST)
print(f"X and y shapes: {X.shape}, {y.shape}")
# Out:
# X and y shapes: torch.Size([9693, 277]), torch.Size([9693, 30])

# %%
(
    X_train,
    y_train,
    X_val,
    y_val,
    X_test,
    y_test,
) = split_train_test_forecast_windows(
    X, y, FORECAST, N_FORECAST_WINDOWS, N_VALIDATION_WINDOWS
)

print(f"Training data shapes: {X_train.shape}, {y_train.shape}")
print(f"Validation data shapes: {X_val.shape}, {y_val.shape}")
print(f"Testing data shapes: {X_test.shape}, {y_test.shape}")
# Out:
# Training data shapes: torch.Size([8790, 277]), torch.Size([8790, 30])
# Validation data shapes: torch.Size([450, 277]), torch.Size([450, 30])
# Testing data shapes: torch.Size([450, 277]), torch.Size([450, 30])

# %%
data_dict, scaler_X, scaler_y = normalise_dataset(
    X_train, y_train, X_test, y_test, X_val, y_val
)
data_dict.keys()
# Out:
# dict_keys(['X_train', 'y_train', 'X_test', 'y_test', 'X_train_sc', 'y_train_sc', 'X_test_sc', 'y_test_sc', 'X_val', 'y_val', 'X_val_sc', 'y_val_sc'])

# %%
plt.figure(figsize=(15, 5))
plt.plot(data_dict["X_test_sc"][10], ".", label="Lookback")
plt.plot(
    np.arange(LOOKBACK, LOOKBACK + FORECAST),
    data_dict["y_test_sc"][10],
    ".",
    label="Forecast",
)
plt.title("X and y Test Sample")
plt.xlabel("Time (days)")
plt.ylabel("Shear Stress (mPa)")
plt.legend()
plt.show()

# %%
N_VARIATES = 1
HIDDEN_SIZE = int(optuna_params["hidden_size"])
KERNEL_SIZE = int(optuna_params["kernel_size"])
OUTPUT_SIZE = FORECAST
DROPOUT = float(optuna_params["dropout"])

model = tcn.MultiStepTCN(
    N_VARIATES, LOOKBACK, OUTPUT_SIZE, [HIDDEN_SIZE], KERNEL_SIZE, DROPOUT
).to(device)

model = load_model(model, MODEL_DIR)[0]
# Out:
# model and data [+ params] loaded from /gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/results/p341cam_TCN_sim_b698_2024-03-05T15:46:48_torch
# /home/users/p341cam/miniconda3/envs/venv/lib/python3.11/site-packages/torch/nn/utils/weight_norm.py:30: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")

# %%
###### Lab data training #########

# %%
set_seed(SEED)

device = set_torch_device()
# Out:
# GPU name: NVIDIA A100-SXM4-40GB
# Max GPU memory: 42.297786368 GiB

# %%
EXP = "b698"

dataset = SlowEarthquakeDataset([EXP])
df = SlowEarthquakeDataset.convert_to_df(dataset, EXP)

df.head()
# Out:
#    obs_shear_stress  obs_normal_stress  obs_ecdisp  obs_shear_strain  time
# 0         11.225116          17.382861   20.088637         22.167371  0.00
# 1         11.222870          17.375571   20.088683         22.167447  0.01
# 2         11.224972          17.385328   20.088975         22.167941  0.02
# 3         11.221124          17.373017   20.088549         22.167221  0.03
# 4         11.225461          17.386512   20.089116         22.168180  0.04

# %%
shear_stress_df = df["obs_shear_stress"]
shear_stress_df.shape
# Out:
# (20001,)

# %%
SMOOTHING_WINDOW = config[EXP]["smoothing_window"]
DOWNSAMPLING_FACTOR = config[EXP]["downsampling_factor"]
df_smoothed = moving_average_causal_filter(
    shear_stress_df, SMOOTHING_WINDOW, DOWNSAMPLING_FACTOR
)
df_smoothed.shape
# Out:
# (10000,)

# %%
results = compare_feature_statistics(shear_stress_df, df_smoothed)
results
# Out:
# {'mean_comparison': {'t_statistic': 0.002753184281868637,
#   'p_value': 0.9978032978502813,
#   'significant': False},
#  'variance_comparison': {'f_statistic': 7.580023683359035e-06,
#   'p_value': 0.997803297844141,
#   'significant': False}}

# %%
plot_original_vs_processed_data(
    shear_stress_df, df_smoothed, "line", "Downsampled"
)

# %%
plot_original_vs_processed_data(
    shear_stress_df, df_smoothed, "scatter", "Downsampled"
)

# %%
X, y = create_dataset(df_smoothed, LOOKBACK, FORECAST)
print(f"X and y shapes: {X.shape}, {y.shape}")
# Out:
# X and y shapes: torch.Size([9694, 277]), torch.Size([9694, 30])

# %%
(
    X_train,
    y_train,
    X_val,
    y_val,
    X_test,
    y_test,
) = split_train_test_forecast_windows(
    X, y, FORECAST, N_FORECAST_WINDOWS, N_VALIDATION_WINDOWS
)

print(f"Training data shapes: {X_train.shape}, {y_train.shape}")
print(f"Validation data shapes: {X_val.shape}, {y_val.shape}")
print(f"Testing data shapes: {X_test.shape}, {y_test.shape}")
# Out:
# Training data shapes: torch.Size([8790, 277]), torch.Size([8790, 30])
# Validation data shapes: torch.Size([450, 277]), torch.Size([450, 30])
# Testing data shapes: torch.Size([450, 277]), torch.Size([450, 30])

# %%
data_dict, scaler_X, scaler_y = normalise_dataset(
    X_train, y_train, X_test, y_test, X_val, y_val
)
data_dict.keys()
# Out:
# dict_keys(['X_train', 'y_train', 'X_test', 'y_test', 'X_train_sc', 'y_train_sc', 'X_test_sc', 'y_test_sc', 'X_val', 'y_val', 'X_val_sc', 'y_val_sc'])

# %%
plt.figure(figsize=(15, 5))
plt.plot(data_dict["X_test_sc"][10], ".", label="Lookback")
plt.plot(
    np.arange(LOOKBACK, LOOKBACK + FORECAST),
    data_dict["y_test_sc"][10],
    ".",
    label="Forecast",
)
plt.title("X and y Test Sample")
plt.xlabel("Time (days)")
plt.ylabel("Shear Stress (mPa)")
plt.legend()
plt.show()

# %%
N_EPOCHS = 25
results_dict = train_model(model, N_EPOCHS, data_dict, scaler_y, device)
# Out:
# Training model on cuda
# Epoch [25/25], Train RMSE: 0.0420, Val RMSE: 0.0474: 100%|████████████████████████████| 25/25 [00:24<00:00,  1.02it/s]

# %%
results_dict = eval_model_on_test_set(
    model, results_dict, data_dict, scaler_y, device
)

# %%
plot_metric_results(
    N_EPOCHS,
    results_dict["train_rmse_list"],
    results_dict["val_rmse_list"],
    "RMSE",
    val_or_test="Val",
)

# %%
plot_metric_results(
    N_EPOCHS,
    results_dict["train_r2_list"],
    results_dict["val_r2_list"],
    "R$^2$",
    val_or_test="Val",
)

# %%
TITLE = "Original Time Series and Model Predictions"
X_LABEL = "Time (days)"
Y_LABEL = "Shear Stress (mPa)"

ZOOM_MIN = 9500
ZOOM_MAX = 10000
ZOOM_WINDOW = [ZOOM_MIN, ZOOM_MAX]

# %%
plot_all_data_results(
    data_dict, results_dict, LOOKBACK, FORECAST, TITLE, X_LABEL, Y_LABEL, []
)

# %%
plot_all_data_results(
    data_dict,
    results_dict,
    LOOKBACK,
    FORECAST,
    TITLE,
    X_LABEL,
    Y_LABEL,
    ZOOM_WINDOW,
)

# %%
###### Cascadia data training #########

# %%
set_seed(SEED)

device = set_torch_device()
# Out:
# GPU name: NVIDIA A100-SXM4-40GB
# Max GPU memory: 42.297786368 GiB

# %%
EXP = "cascadia"

dataset = SlowEarthquakeDataset([EXP])
df = SlowEarthquakeDataset.convert_to_df(dataset, EXP)

df.head()
# Out:
#         seg_avg          seg_0          seg_1          seg_2          seg_3  \
# 0  1.510314e+08   87022.678176  -51216.196044 -195371.505863 -252388.298108
# 1  1.256806e+08  118857.552212   64765.192887  -66943.170211 -125253.475061
# 2  1.074901e+08 -113120.619296 -100329.909243 -117236.092138  -63257.566664
# 3  1.447256e+08  -51897.143096  -61146.543996 -108560.424295  -80686.019435
# 4  1.787377e+08  -60139.943735 -118351.239477 -228181.280629 -226276.200039
#
#            seg_4          seg_5          seg_6          seg_7          seg_8  \
# 0  372090.056832  290238.755195  271991.646241  218795.685053   87096.609524
# 1  510980.726973  375269.217942  323695.517273  312924.577753   -6911.497818
# 2   87699.655400   15131.208777  -22576.356489  -13975.055467 -177396.925200
# 3  178525.612880   98101.791008   48849.079713   53199.150697 -139909.026614
# 4  270908.204014  154758.192851   92016.023222   86065.362414 -174784.005040
#
#    ...        seg_187        seg_188        seg_189       seg_190  \
# 0  ... -714770.112748 -631423.743396 -693599.810348 -7.208255e+05
# 1  ... -506075.873333 -448764.275644 -391456.474306 -9.886575e+05
# 2  ... -421853.932989 -333693.022748 -204519.903296 -7.137062e+05
# 3  ... -655215.504038 -473799.573780 -345621.989210 -9.187762e+05
# 4  ... -916992.338832 -753637.001609 -546489.401328 -1.036981e+06
#
#          seg_191        seg_192       seg_193        seg_194        seg_195  \
# 0 -739527.228854 -471014.225482 -6.757540e+05 -350155.612260 -517024.526987
# 1 -958004.348328 -740390.446945 -8.927657e+05 -466337.939160 -928475.702850
# 2 -715494.785171 -542145.799983 -6.803446e+05 -366915.287037 -572674.592498
# 3 -927868.499626 -679886.516377 -8.823582e+05 -474262.121982 -695698.483285
# 4 -934869.092836 -938970.117667 -1.106399e+06 -800182.900760 -897332.083419
#
#           time
# 0  2007.000700
# 1  2007.003438
# 2  2007.006176
# 3  2007.008914
# 4  2007.011651
#
# [5 rows x 198 columns]

# %%
segment_df = df["seg_avg"] / 1e8
segment_df.shape
# Out:
# (3883,)

# %%
SMOOTHING_WINDOW = config[EXP]["smoothing_window"]
DOWNSAMPLING_FACTOR = config[EXP]["downsampling_factor"]
df_smoothed = moving_average_causal_filter(
    segment_df, SMOOTHING_WINDOW, DOWNSAMPLING_FACTOR
)
df_smoothed.shape
# Out:
# (3874,)

# %%
results = compare_feature_statistics(segment_df, df_smoothed)
results
# Out:
# {'mean_comparison': {'t_statistic': 0.048536835802983076,
#   'p_value': 0.961289658191594,
#   'significant': False},
#  'variance_comparison': {'f_statistic': 0.002355824429765806,
#   'p_value': 0.9612896581873488,
#   'significant': False}}

# %%
plot_original_vs_processed_data(segment_df, df_smoothed, "line", "Downsampled")

# %%
plot_original_vs_processed_data(
    segment_df, df_smoothed, "scatter", "Downsampled"
)

# %%
X, y = create_dataset(df_smoothed, LOOKBACK, FORECAST)
print(f"X and y shapes: {X.shape}, {y.shape}")
# Out:
# X and y shapes: torch.Size([3568, 277]), torch.Size([3568, 30])

# %%
(
    X_train,
    y_train,
    X_val,
    y_val,
    X_test,
    y_test,
) = split_train_test_forecast_windows(
    X, y, FORECAST, N_FORECAST_WINDOWS, N_VALIDATION_WINDOWS
)

print(f"Training data shapes: {X_train.shape}, {y_train.shape}")
print(f"Validation data shapes: {X_val.shape}, {y_val.shape}")
print(f"Testing data shapes: {X_test.shape}, {y_test.shape}")
# Out:
# Training data shapes: torch.Size([2640, 277]), torch.Size([2640, 30])
# Validation data shapes: torch.Size([450, 277]), torch.Size([450, 30])
# Testing data shapes: torch.Size([450, 277]), torch.Size([450, 30])

# %%
data_dict, scaler_X, scaler_y = normalise_dataset(
    X_train, y_train, X_test, y_test, X_val, y_val
)
data_dict.keys()
# Out:
# dict_keys(['X_train', 'y_train', 'X_test', 'y_test', 'X_train_sc', 'y_train_sc', 'X_test_sc', 'y_test_sc', 'X_val', 'y_val', 'X_val_sc', 'y_val_sc'])

# %%
plt.figure(figsize=(15, 5))
plt.plot(data_dict["X_test_sc"][10], ".", label="Lookback")
plt.plot(
    np.arange(LOOKBACK, LOOKBACK + FORECAST),
    data_dict["y_test_sc"][10],
    ".",
    label="Forecast",
)
plt.title("X and y Test Sample")
plt.xlabel("Time (days)")
plt.ylabel("Shear Stress (mPa)")
plt.legend()
plt.show()

# %%
N_EPOCHS = 3
results_dict = train_model(model, N_EPOCHS, data_dict, scaler_y, device)
# Out:
# Training model on cuda
# Epoch [3/3], Train RMSE: 0.2721, Val RMSE: 0.3564: 100%|████████████████████████████████| 3/3 [00:01<00:00,  2.03it/s]

# %%
results_dict = eval_model_on_test_set(
    model, results_dict, data_dict, scaler_y, device
)

# %%
plot_metric_results(
    N_EPOCHS,
    results_dict["train_rmse_list"],
    results_dict["val_rmse_list"],
    "RMSE",
    val_or_test="Val",
)

# %%
plot_metric_results(
    N_EPOCHS,
    results_dict["train_r2_list"],
    results_dict["val_r2_list"],
    "R$^2$",
    val_or_test="Val",
)

# %%
TITLE = "Original Time Series and Model Predictions"
X_LABEL = "Time (days)"
Y_LABEL = "Slip Displacement Potency ($m^3$)"

ZOOM_MIN = 3200
ZOOM_MAX = 4000
ZOOM_WINDOW = [ZOOM_MIN, ZOOM_MAX]

# %%
plot_all_data_results(
    data_dict, results_dict, LOOKBACK, FORECAST, TITLE, X_LABEL, Y_LABEL, []
)

# %%
plot_all_data_results(
    data_dict,
    results_dict,
    LOOKBACK,
    FORECAST,
    TITLE,
    X_LABEL,
    Y_LABEL,
    ZOOM_WINDOW,
)

# %%
###### Regular Cascadia data training #########

# %%
set_seed(SEED)

device = set_torch_device()
# Out:
# GPU name: NVIDIA A100-SXM4-40GB
# Max GPU memory: 42.297786368 GiB

# %%
OPTUNA_PARAMS_PATH = "/gws/nopw/j04/ai4er/users/pn341/earthquake-predictability/scripts/optuna_results/p341cam_best_TCN_cascadia_2024-03-05T16:23:25.csv"

import csv

reader = csv.reader(open(OPTUNA_PARAMS_PATH, "r"))
optuna_params = {}
for row in reader:
    k, v = row
    optuna_params[k] = v

optuna_params
# Out:
# {'hidden_size': '64', 'kernel_size': '8', 'dropout': '0.29817264887983463'}

# %%
N_VARIATES = 1
HIDDEN_SIZE = int(optuna_params["hidden_size"])
KERNEL_SIZE = int(optuna_params["kernel_size"])
OUTPUT_SIZE = FORECAST
DROPOUT = float(optuna_params["dropout"])

model = tcn.MultiStepTCN(
    N_VARIATES, LOOKBACK, OUTPUT_SIZE, [HIDDEN_SIZE], KERNEL_SIZE, DROPOUT
).to(device)
# Out:
# /home/users/p341cam/miniconda3/envs/venv/lib/python3.11/site-packages/torch/nn/utils/weight_norm.py:30: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")

# %%
N_EPOCHS = 25
results_dict = train_model(model, N_EPOCHS, data_dict, scaler_y, device)
# Out:
# Training model on cuda
# Epoch [25/25], Train RMSE: 0.2939, Val RMSE: 0.3797: 100%|████████████████████████████| 25/25 [00:11<00:00,  2.22it/s]

# %%
results_dict = eval_model_on_test_set(
    model, results_dict, data_dict, scaler_y, device
)

# %%
plot_metric_results(
    N_EPOCHS,
    results_dict["train_rmse_list"],
    results_dict["val_rmse_list"],
    "RMSE",
    val_or_test="Val",
)

# %%
plot_metric_results(
    N_EPOCHS,
    results_dict["train_r2_list"],
    results_dict["val_r2_list"],
    "R$^2$",
    val_or_test="Val",
)

# %%
TITLE = "Original Time Series and Model Predictions"
X_LABEL = "Time (days)"
Y_LABEL = "Slip Displacement Potency ($m^3$)"

ZOOM_MIN = 3200
ZOOM_MAX = 4000
ZOOM_WINDOW = [ZOOM_MIN, ZOOM_MAX]

# %%
plot_all_data_results(
    data_dict, results_dict, LOOKBACK, FORECAST, TITLE, X_LABEL, Y_LABEL, []
)

# %%
plot_all_data_results(
    data_dict,
    results_dict,
    LOOKBACK,
    FORECAST,
    TITLE,
    X_LABEL,
    Y_LABEL,
    ZOOM_WINDOW,
)
